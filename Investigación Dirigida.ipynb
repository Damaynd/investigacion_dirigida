# %%
import matplotlib.pyplot as plt
from matplotlib import transforms
from matplotlib import rc
from IPython.display import Image
import numpy as np
from astropy.io import fits as pyfits

# %%
from gt_apps import filter

# %%
filter.pars()
# Out:
# ' infile=@BBJ11_events.txt outfile=BBJ11_filtered.fits ra=177.645 dec=41.9111 rad=10.0 tmin=239557471.0 tmax=498411817.0 emin=30.0 emax=300000.0 zmin=0.0 zmax=100.0 evclass="INDEF" evtype="INDEF" convtype=-1 phasemin=0.0 phasemax=1.0 evtable="EVENTS" chatter=2 clobber=yes debug=no gui=no mode="ql"'

# %%
# Hacemos el filtro de los datos según los parámetros definidos para cada fuente #
filter['infile'] = '3C66A_events.txt'
filter['outfile'] = '3C66A_filtered.fits'
filter['ra'] = 35.665
filter['dec'] = 43.0355
filter['rad'] = 10
filter['tmin'] = 239557417
filter['tmax'] = 498411817
filter['emin'] = 33.6803
filter['emax'] = 300000
filter['zmax'] = 100
filter['evclass'] = 128
filter['evtype'] = 3
filter.run()
# Out:
# time -p gtselect infile=3C66A_events.txt outfile=3C66A_filtered.fits ra=35.665 dec=43.0355 rad=10.0 tmin=239557417.0 tmax=498411817.0 emin=33.6803 emax=300000.0 zmin=0.0 zmax=100.0 evclass=128 evtype=3 convtype=-1 phasemin=0.0 phasemax=1.0 evtable="EVENTS" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# Done.
# real 29.10
# user 27.08
# sys 2.14

# %%
filter['infile'] = 'BBJ01_events.txt'
filter['outfile'] = 'BBJ01_filtered.fits'
filter['ra'] = 24.1358
filter['dec'] = 39.0998
filter['rad'] = 10
filter['tmin'] = 239557417
filter['tmax'] = 498411817
filter['emin'] = 33.6803
filter['emax'] = 300000
filter['zmax'] = 100
filter['evclass'] = 128
filter['evtype'] = 3
filter.run()
# Out:
# time -p gtselect infile=BBJ01_events.txt outfile=BBJ01_filtered.fits ra=24.1358 dec=39.0998 rad=10.0 tmin=239557417.0 tmax=498411817.0 emin=33.6803 emax=300000.0 zmin=0.0 zmax=100.0 evclass=128 evtype=3 convtype=-1 phasemin=0.0 phasemax=1.0 evtable="EVENTS" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# Done.
# real 24.04
# user 20.45
# sys 3.78

# %%
filter['infile'] = 'BBJ11_events.txt'
filter['outfile'] = 'BBJ11_filtered.fits'
filter['ra'] = 177.645
filter['dec'] = 41.9111
filter['rad'] = 10
filter['tmin'] = 239557417
filter['tmax'] = 498411817
filter['emin'] = 33.6803
filter['emax'] = 300000
filter['zmax'] = 100
filter['evclass'] = 128
filter['evtype'] = 3
filter.run()
# Out:
# time -p gtselect infile=BBJ11_events.txt outfile=BBJ11_filtered.fits ra=177.645 dec=41.9111 rad=10.0 tmin=239557417.0 tmax=498411817.0 emin=33.6803 emax=300000.0 zmin=0.0 zmax=100.0 evclass=128 evtype=3 convtype=-1 phasemin=0.0 phasemax=1.0 evtable="EVENTS" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# Done.
# real 19.78
# user 17.40
# sys 1.79

# %%
# Hacemos los cortes de los intervalos de tiempo GTI (¿cómo imponer los intervalos dados?) #
from gt_apps import maketime
maketime['evfile'] = '3C66A_filtered.fits'
maketime['outfile'] = '3C66A_mktime.fits'
maketime['scfile'] = '3C66A_SC.fits'
maketime['filter'] = 'DATA_QUAL>0 && LAT_CONFIG==1'
maketime['apply_filter'] = 'yes'
maketime['roicut'] = 'no'
maketime.run()
# Out:
# time -p gtmktime scfile=3C66A_SC.fits sctable="SC_DATA" filter="DATA_QUAL>0 && LAT_CONFIG==1" roicut=no evfile=3C66A_filtered.fits evtable="EVENTS" outfile="3C66A_mktime.fits" apply_filter=yes overwrite=no header_obstimes=yes tstart=0.0 tstop=0.0 gtifile="default" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# real 149.73
# user 141.98
# sys 1.24

# %%
maketime['evfile'] = 'BBJ01_filtered.fits'
maketime['outfile'] = 'BBJ01_mktime.fits'
maketime['scfile'] = 'BBJ01_SC.fits'
maketime['filter'] = 'DATA_QUAL>0 && LAT_CONFIG==1'
maketime['apply_filter'] = 'yes'
maketime['roicut'] = 'no'
maketime.run()
# Out:
# time -p gtmktime scfile=BBJ01_SC.fits sctable="SC_DATA" filter="DATA_QUAL>0 && LAT_CONFIG==1" roicut=no evfile=BBJ01_filtered.fits evtable="EVENTS" outfile="BBJ01_mktime.fits" apply_filter=yes overwrite=no header_obstimes=yes tstart=0.0 tstop=0.0 gtifile="default" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# real 157.48
# user 149.00
# sys 1.28

# %%
maketime['evfile'] = 'BBJ11_filtered.fits'
maketime['outfile'] = 'BBJ11_mktime.fits'
maketime['scfile'] = 'BBJ11_SC.fits'
maketime['filter'] = 'DATA_QUAL>0 && LAT_CONFIG==1'
maketime['apply_filter'] = 'yes'
maketime['roicut'] = 'no'
maketime.run()
# Out:
# time -p gtmktime scfile=BBJ11_SC.fits sctable="SC_DATA" filter="DATA_QUAL>0 && LAT_CONFIG==1" roicut=no evfile=BBJ11_filtered.fits evtable="EVENTS" outfile="BBJ11_mktime.fits" apply_filter=yes overwrite=no header_obstimes=yes tstart=0.0 tstop=0.0 gtifile="default" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# real 167.77
# user 159.68
# sys 1.36

# %%
# Hacemos nuestro count map para cada fuente #
from gt_apps import evtbin
evtbin['evfile'] = '3C66A_mktime.fits'
evtbin['outfile'] = '3C66A_cmap.fits'
evtbin['algorithm'] = 'cmap'
evtbin['nxpix'] = 100
evtbin['nypix'] = 100
evtbin['binsz'] = 0.2
evtbin['coordsys'] = 'CEL'
evtbin['xref'] = 35.665
evtbin['yref'] = 43.0355
evtbin['axisrot'] = 0.0
evtbin['proj'] = 'CAR'
evtbin.run()
# Out:
# time -p gtbin evfile=3C66A_mktime.fits scfile=NONE outfile=3C66A_cmap.fits algorithm="cmap" ebinalg="LOG" emin=30.0 emax=200000.0 enumbins=0 denergy=0.0 ebinfile=NONE tbinalg="LIN" tstart=239557471.0 tstop=498411817.0 dtime=604800.0 tbinfile=NONE snratio=0.0 lcemin=0.0 lcemax=0.0 nxpix=100 nypix=100 binsz=0.2 coordsys="CEL" xref=35.665 yref=43.0355 axisrot=0.0 rafield="RA" decfield="DEC" proj="CAR" hpx_ordering_scheme="RING" hpx_order=3 hpx_ebin=yes hpx_region="" evtable="EVENTS" sctable="SC_DATA" efield="ENERGY" tfield="TIME" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# This is gtbin version HEAD
# gtbin: WARNING: No spacecraft file: EXPOSURE keyword will be set equal to ontime.
# real 1.40
# user 1.07
# sys 0.47

# %%
evtbin['evfile'] = 'BBJ01_mktime.fits'
evtbin['outfile'] = 'BBJ01_cmap.fits'
evtbin['algorithm'] = 'cmap'
evtbin['nxpix'] = 100
evtbin['nypix'] = 100
evtbin['binsz'] = 0.2
evtbin['coordsys'] = 'CEL'
evtbin['xref'] = 24.1358
evtbin['yref'] = 39.0998
evtbin['axisrot'] = 0.0
evtbin['proj'] = 'CAR'
evtbin.run()
# Out:
# time -p gtbin evfile=BBJ01_mktime.fits scfile=NONE outfile=BBJ01_cmap.fits algorithm="cmap" ebinalg="LOG" emin=30.0 emax=200000.0 enumbins=0 denergy=0.0 ebinfile=NONE tbinalg="LIN" tstart=239557471.0 tstop=498411817.0 dtime=604800.0 tbinfile=NONE snratio=0.0 lcemin=0.0 lcemax=0.0 nxpix=100 nypix=100 binsz=0.2 coordsys="CEL" xref=24.1358 yref=39.0998 axisrot=0.0 rafield="RA" decfield="DEC" proj="CAR" hpx_ordering_scheme="RING" hpx_order=3 hpx_ebin=yes hpx_region="" evtable="EVENTS" sctable="SC_DATA" efield="ENERGY" tfield="TIME" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# This is gtbin version HEAD
# gtbin: WARNING: No spacecraft file: EXPOSURE keyword will be set equal to ontime.
# real 1.00
# user 0.90
# sys 0.43

# %%
evtbin['evfile'] = 'BBJ11_mktime.fits'
evtbin['outfile'] = 'BBJ11_cmap.fits'
evtbin['algorithm'] = 'cmap'
evtbin['nxpix'] = 100
evtbin['nypix'] = 100
evtbin['binsz'] = 0.2
evtbin['coordsys'] = 'CEL'
evtbin['xref'] = 177.645
evtbin['yref'] = 41.9111
evtbin['axisrot'] = 0.0
evtbin['proj'] = 'CAR'
evtbin.run()
# Out:
# time -p gtbin evfile=BBJ11_mktime.fits scfile=NONE outfile=BBJ11_cmap.fits algorithm="cmap" ebinalg="LOG" emin=30.0 emax=200000.0 enumbins=0 denergy=0.0 ebinfile=NONE tbinalg="LIN" tstart=239557471.0 tstop=498411817.0 dtime=604800.0 tbinfile=NONE snratio=0.0 lcemin=0.0 lcemax=0.0 nxpix=100 nypix=100 binsz=0.2 coordsys="CEL" xref=177.645 yref=41.9111 axisrot=0.0 rafield="RA" decfield="DEC" proj="CAR" hpx_ordering_scheme="RING" hpx_order=3 hpx_ebin=yes hpx_region="" evtable="EVENTS" sctable="SC_DATA" efield="ENERGY" tfield="TIME" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# This is gtbin version HEAD
# gtbin: WARNING: No spacecraft file: EXPOSURE keyword will be set equal to ontime.
# real 0.79
# user 0.80
# sys 0.33

# %%
cmap_hdu1 = pyfits.open('3C66A_cmap.fits')
cmap_hdu2 = pyfits.open('BBJ01_cmap.fits')
cmap_hdu3 = pyfits.open('BBJ11_cmap.fits')

fig = plt.figure(figsize=(10, 10))
plt.imshow(cmap_hdu1[0].data,origin='lower')
plt.annotate(
    '', xy=(0, 90), xycoords = 'data',
    xytext = (40, 90), textcoords = 'data',
    arrowprops = {'facecolor':'white','edgecolor':'white'})
plt.annotate(
    '', xy=(99, 90), xycoords = 'data',
    xytext = (40, 90), textcoords = 'data',
    arrowprops = {'facecolor':'white','edgecolor':'white'})
plt.text(40, 85, '10 Degrees',fontsize=20,color='white')
plt.text(65,-15,"0.03 GeV - 300 GeV",fontsize=20)
plt.xlabel('Pixels')
plt.ylabel('Pixels')
plt.show()

# %%
fig = plt.figure(figsize=(10, 10))
plt.imshow(cmap_hdu2[0].data,origin='lower')
plt.annotate(
    '', xy=(0, 90), xycoords = 'data',
    xytext = (40, 90), textcoords = 'data',
    arrowprops = {'facecolor':'white','edgecolor':'white'})
plt.annotate(
    '', xy=(99, 90), xycoords = 'data',
    xytext = (40, 90), textcoords = 'data',
    arrowprops = {'facecolor':'white','edgecolor':'white'})
plt.text(40, 85, '10 Degrees',fontsize=20,color='white')
plt.text(65,-15,"0.03 GeV - 300 GeV",fontsize=20)
plt.xlabel('Pixels')
plt.ylabel('Pixels')
plt.show()

# %%
fig = plt.figure(figsize=(10, 10))
plt.imshow(cmap_hdu3[0].data,origin='lower')
plt.annotate(
    '', xy=(0, 90), xycoords = 'data',
    xytext = (40, 90), textcoords = 'data',
    arrowprops = {'facecolor':'white','edgecolor':'white'})
plt.annotate(
    '', xy=(99, 90), xycoords = 'data',
    xytext = (40, 90), textcoords = 'data',
    arrowprops = {'facecolor':'white','edgecolor':'white'})
plt.text(40, 85, '10 Degrees',fontsize=20,color='white')
plt.text(65,-15,"0.03 GeV - 300 GeV",fontsize=20)
plt.xlabel('Pixels')
plt.ylabel('Pixels')
plt.show()

# %%
# Hacemos los livetime cubes para cada fuente #
evtbin['algorithm'] = 'CCUBE'
evtbin['evfile'] = '3C66A_mktime.fits'
evtbin['outfile'] = '3C66A_ccube.fits'
evtbin['nxpix'] = 100
evtbin['nypix'] = 100
evtbin['binsz'] = 0.2
evtbin['coordsys'] = 'CEL'
evtbin['xref'] = 35.665
evtbin['yref'] = 43.0355
evtbin['axisrot'] = 0.0
evtbin['proj'] = 'CAR'
evtbin['ebinalg'] = 'LOG'
evtbin['emin'] = 33.6803
evtbin['emax'] = 300000
evtbin['enumbins'] = 20
evtbin.run()
# Out:
# time -p gtbin evfile=3C66A_mktime.fits scfile=NONE outfile=3C66A_ccube.fits algorithm="CCUBE" ebinalg="LOG" emin=33.6803 emax=300000.0 enumbins=20 denergy=0.0 ebinfile=NONE tbinalg="LIN" tstart=239557471.0 tstop=498411817.0 dtime=604800.0 tbinfile=NONE snratio=0.0 lcemin=0.0 lcemax=0.0 nxpix=100 nypix=100 binsz=0.2 coordsys="CEL" xref=35.665 yref=43.0355 axisrot=0.0 rafield="RA" decfield="DEC" proj="CAR" hpx_ordering_scheme="RING" hpx_order=3 hpx_ebin=yes hpx_region="" evtable="EVENTS" sctable="SC_DATA" efield="ENERGY" tfield="TIME" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# This is gtbin version HEAD
# gtbin: WARNING: No spacecraft file: EXPOSURE keyword will be set equal to ontime.
# real 1.66
# user 1.52
# sys 0.44

# %%
evtbin['algorithm'] = 'CCUBE'
evtbin['evfile'] = 'BBJ01_mktime.fits'
evtbin['outfile'] = 'BBJ01_ccube.fits'
evtbin['nxpix'] = 100
evtbin['nypix'] = 100
evtbin['binsz'] = 0.2
evtbin['coordsys'] = 'CEL'
evtbin['xref'] = 24.1358
evtbin['yref'] = 39.0998
evtbin['axisrot'] = 0.0
evtbin['proj'] = 'CAR'
evtbin['ebinalg'] = 'LOG'
evtbin['emin'] = 33.6803
evtbin['emax'] = 300000
evtbin['enumbins'] = 20
evtbin.run()
# Out:
# time -p gtbin evfile=BBJ01_mktime.fits scfile=NONE outfile=BBJ01_ccube.fits algorithm="CCUBE" ebinalg="LOG" emin=33.6803 emax=300000.0 enumbins=20 denergy=0.0 ebinfile=NONE tbinalg="LIN" tstart=239557471.0 tstop=498411817.0 dtime=604800.0 tbinfile=NONE snratio=0.0 lcemin=0.0 lcemax=0.0 nxpix=100 nypix=100 binsz=0.2 coordsys="CEL" xref=24.1358 yref=39.0998 axisrot=0.0 rafield="RA" decfield="DEC" proj="CAR" hpx_ordering_scheme="RING" hpx_order=3 hpx_ebin=yes hpx_region="" evtable="EVENTS" sctable="SC_DATA" efield="ENERGY" tfield="TIME" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# This is gtbin version HEAD
# gtbin: WARNING: No spacecraft file: EXPOSURE keyword will be set equal to ontime.
# real 1.33
# user 1.14
# sys 0.37

# %%
evtbin['algorithm'] = 'CCUBE'
evtbin['evfile'] = 'BBJ11_mktime.fits'
evtbin['outfile'] = 'BBJ11_ccube.fits'
evtbin['nxpix'] = 100
evtbin['nypix'] = 100
evtbin['binsz'] = 0.2
evtbin['coordsys'] = 'CEL'
evtbin['xref'] = 177.645
evtbin['yref'] = 41.9111
evtbin['axisrot'] = 0.0
evtbin['proj'] = 'CAR'
evtbin['ebinalg'] = 'LOG'
evtbin['emin'] = 33.6803
evtbin['emax'] = 300000
evtbin['enumbins'] = 20
evtbin.run()
# Out:
# time -p gtbin evfile=BBJ11_mktime.fits scfile=NONE outfile=BBJ11_ccube.fits algorithm="CCUBE" ebinalg="LOG" emin=33.6803 emax=300000.0 enumbins=20 denergy=0.0 ebinfile=NONE tbinalg="LIN" tstart=239557471.0 tstop=498411817.0 dtime=604800.0 tbinfile=NONE snratio=0.0 lcemin=0.0 lcemax=0.0 nxpix=100 nypix=100 binsz=0.2 coordsys="CEL" xref=177.645 yref=41.9111 axisrot=0.0 rafield="RA" decfield="DEC" proj="CAR" hpx_ordering_scheme="RING" hpx_order=3 hpx_ebin=yes hpx_region="" evtable="EVENTS" sctable="SC_DATA" efield="ENERGY" tfield="TIME" chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# This is gtbin version HEAD
# gtbin: WARNING: No spacecraft file: EXPOSURE keyword will be set equal to ontime.
# real 1.06
# user 0.94
# sys 0.35

# %%
# Generamos el livetime cube para las fuentes #
from gt_apps import expCube
expCube['evfile'] = '3C66A_mktime.fits'
expCube['scfile'] = '3C66A_SC.fits'
expCube['outfile'] = '3C66A_ltcube.fits'
expCube['dcostheta'] = 0.025
expCube['binsz'] = 1.0
expCube['zmax'] = 100
expCube.run()
# Out:
# time -p gtltcube evfile="3C66A_mktime.fits" evtable="EVENTS" scfile=3C66A_SC.fits sctable="SC_DATA" outfile=3C66A_ltcube.fits dcostheta=0.025 binsz=1.0 phibins=0 tmin=0.0 tmax=0.0 file_version="1" zmin=0.0 zmax=100.0 chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# Working on file 3C66A_SC.fits
# .....................!
# real 5161.68
# user 5153.48
# sys 1.79

# %%
expCube['evfile'] = 'BBJ01_mktime.fits'
expCube['scfile'] = 'BBJ01_SC.fits'
expCube['outfile'] = 'BBJ01_ltcube.fits'
expCube['dcostheta'] = 0.025
expCube['binsz'] = 1.0
expCube['zmax'] = 100
expCube.run()
# Out:
# time -p gtltcube evfile="BBJ01_mktime.fits" evtable="EVENTS" scfile=BBJ01_SC.fits sctable="SC_DATA" outfile=BBJ01_ltcube.fits dcostheta=0.025 binsz=1.0 phibins=0 tmin=0.0 tmax=0.0 file_version="1" zmin=0.0 zmax=100.0 chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# Working on file BBJ01_SC.fits
# .....................!
# real 5284.61
# user 5276.85
# sys 1.27

# %%
expCube['evfile'] = 'BBJ11_mktime.fits'
expCube['scfile'] = 'BBJ11_SC.fits'
expCube['outfile'] = 'BBJ11_ltcube.fits'
expCube['dcostheta'] = 0.025
expCube['binsz'] = 1.0
expCube['zmax'] = 100
expCube.run()
# Out:
# time -p gtltcube evfile="BBJ11_mktime.fits" evtable="EVENTS" scfile=BBJ11_SC.fits sctable="SC_DATA" outfile=BBJ11_ltcube.fits dcostheta=0.025 binsz=1.0 phibins=0 tmin=0.0 tmax=0.0 file_version="1" zmin=0.0 zmax=100.0 chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# Working on file BBJ11_SC.fits
# .....................!
# real 5083.09
# user 5076.23
# sys 1.31

# %%
from gt_apps import gtexpcube2

# %%
from gt_apps import gtexpcube2
gtexpcube2['infile'] = '3C66A_ltcube.fits'
gtexpcube2['cmap'] = '3C66A_ccube.fits'
gtexpcube2['outfile'] = '3C66A_expcube.fits'
gtexpcube2['nxpix'] = 360
gtexpcube2['nypix'] = 180
gtexpcube2['binsz'] = 1.0
gtexpcube2['coordsys'] = 'CEL'
gtexpcube2['xref'] = 35.665
gtexpcube2['yref'] = 43.0355
gtexpcube2['axisrot'] = 0.0
gtexpcube2['proj'] = 'CAR'
gtexpcube2['ebinalg'] = 'LOG'
gtexpcube2['emin'] = 33.6803
gtexpcube2['emax'] = 300000
gtexpcube2['enumbins'] = 500
gtexpcube2['irfs'] = 'P8R3_SOURCE_V2'
gtexpcube2.run()
# Out:
# time -p gtexpcube2 infile=3C66A_ltcube.fits cmap=3C66A_ccube.fits outfile=3C66A_expcube.fits irfs="P8R3_SOURCE_V2" evtype="INDEF" edisp_bins=0 nxpix=360 nypix=180 binsz=1.0 coordsys="CEL" xref=35.665 yref=43.0355 axisrot=0.0 proj="CAR" ebinalg="LOG" emin=33.6803 emax=300000.0 enumbins=500 ebinfile="NONE" hpx_ordering_scheme="RING" hpx_order=6 bincalc="EDGE" ignorephi=no thmax=180.0 thmin=0.0 table="EXPOSURE" chatter=2 clobber=yes debug=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# Computing binned exposure map....................!
# real 96.03
# user 95.47
# sys 0.79

# %%
gtexpcube2['infile'] = 'BBJ01_ltcube.fits'
gtexpcube2['cmap'] = 'BBJ01_ccube.fits'
gtexpcube2['outfile'] = 'BBJ01_expcube.fits'
gtexpcube2['nxpix'] = 360
gtexpcube2['nypix'] = 180
gtexpcube2['binsz'] = 1.0
gtexpcube2['coordsys'] = 'CEL'
gtexpcube2['xref'] = 24.1358
gtexpcube2['yref'] = 39.0998
gtexpcube2['axisrot'] = 0.0
gtexpcube2['proj'] = 'CAR'
gtexpcube2['ebinalg'] = 'LOG'
gtexpcube2['emin'] = 33.6803
gtexpcube2['emax'] = 300000
gtexpcube2['enumbins'] = 500
gtexpcube2['irfs'] = 'P8R3_SOURCE_V2'
gtexpcube2.run()
# Out:
# time -p gtexpcube2 infile=BBJ01_ltcube.fits cmap=BBJ01_ccube.fits outfile=BBJ01_expcube.fits irfs="P8R3_SOURCE_V2" evtype="INDEF" edisp_bins=0 nxpix=360 nypix=180 binsz=1.0 coordsys="CEL" xref=24.1358 yref=39.0998 axisrot=0.0 proj="CAR" ebinalg="LOG" emin=33.6803 emax=300000.0 enumbins=500 ebinfile="NONE" hpx_ordering_scheme="RING" hpx_order=6 bincalc="EDGE" ignorephi=no thmax=180.0 thmin=0.0 table="EXPOSURE" chatter=2 clobber=yes debug=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# Computing binned exposure map....................!
# real 95.27
# user 94.47
# sys 0.93

# %%
gtexpcube2['infile'] = 'BBJ11_ltcube.fits'
gtexpcube2['cmap'] = 'BBJ11_ccube.fits'
gtexpcube2['outfile'] = 'BBJ11_expcube.fits'
gtexpcube2['nxpix'] = 360
gtexpcube2['nypix'] = 180
gtexpcube2['binsz'] = 1.0
gtexpcube2['coordsys'] = 'CEL'
gtexpcube2['xref'] = 177.645
gtexpcube2['yref'] = 41.9111
gtexpcube2['axisrot'] = 0.0
gtexpcube2['proj'] = 'CAR'
gtexpcube2['ebinalg'] = 'LOG'
gtexpcube2['emin'] = 33.6803
gtexpcube2['emax'] = 300000
gtexpcube2['enumbins'] = 500
gtexpcube2['irfs'] = 'P8R3_SOURCE_V2'
gtexpcube2.run()
# Out:
# time -p gtexpcube2 infile=BBJ11_ltcube.fits cmap=BBJ11_ccube.fits outfile=BBJ11_expcube.fits irfs="iso_p7v6source.txt" evtype="INDEF" edisp_bins=0 nxpix=360 nypix=180 binsz=1.0 coordsys="CEL" xref=177.645 yref=41.9111 axisrot=0.0 proj="CAR" ebinalg="LOG" emin=33.6803 emax=300000.0 enumbins=500 ebinfile="NONE" hpx_ordering_scheme="RING" hpx_order=6 bincalc="EDGE" ignorephi=no thmax=180.0 thmin=0.0 table="EXPOSURE" chatter=2 clobber=yes debug=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# Caught St16invalid_argument at the top level: Invalid response function choice: iso_p7v6source.txt
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-10-a1e7a0f1e9eb> in <module>()
#      15 gtexpcube2['enumbins'] = 500
#      16 gtexpcube2['irfs'] = 'iso_p7v6source.txt'
# ---> 17 gtexpcube2.run()
#
# ...

# %%
from gt_apps import srcMaps
srcMaps['expcube'] = '3C66A_ltcube.fits'
srcMaps['cmap'] = '3C66A_ccube.fits'
srcMaps['srcmdl'] = '3C66A_model.xml'
srcMaps['bexpmap'] = '3C66A_expcube.fits'
srcMaps['outfile'] = '3C66A_srcmaps.fits'
srcMaps['irfs'] = 'CALDB'
srcMaps.run()
# Out:
# time -p gtsrcmaps scfile= sctable="SC_DATA" expcube=3C66A_ltcube.fits cmap=3C66A_ccube.fits srcmdl=3C66A_model.xml bexpmap=3C66A_expcube.fits wmap=none outfile=3C66A_srcmaps.fits irfs="CALDB" evtype="INDEF" convol=yes resample=yes rfactor=2 minbinsz=0.1 ptsrc=yes psfcorr=yes emapbnds=yes edisp_bins=0 copyall=no chatter=2 clobber=yes debug=no gui=no mode="ql"
#
# WARNING: version mismatch between CFITSIO header (v3.43) and linked library (v3.41).
#
# Generating SourceMap for 4FGL J0039.1+4330 21....................!
# Generating SourceMap for 4FGL J0039.7+4203 21....................!
# Generating SourceMap for 4FGL J0040.3+4050 21....................!
# Generating SourceMap for 4FGL J0041.4+3800 21....................!
# Generating SourceMap for 4FGL J0043.2+4114 21....................!
# Generating SourceMap for 4FGL J0047.9+3947 21....................!
# Generating SourceMap for 4FGL J0047.9+5448 21....................!
# ...

# %%
srcMaps['expcube'] = 'BBJ01_ltcube.fits'
srcMaps['cmap'] = 'BBJ01_ccube.fits'
srcMaps['srcmdl'] = 'BBJ01_model.xml'
srcMaps['bexpmap'] = 'BBJ01_expcube.fits'
srcMaps['outfile'] = 'BBJ01_srcmaps.fits'
srcMaps['irfs'] = 'CALDB'
srcMaps.run()

# %%
srcMaps['expcube'] = 'BBJ11_ltcube.fits'
srcMaps['cmap'] = 'BBJ11_ccube.fits'
srcMaps['srcmdl'] = 'BBJ11_model.xml'
srcMaps['bexpmap'] = 'BBJ11_expcube.fits'
srcMaps['outfile'] = 'BBJ11_srcmaps.fits'
srcMaps['irfs'] = 'CALDB'
srcMaps.run()

# %%
from matplotlib.colors import LogNorm

gal_diff = pyfits.open("gll_iem_v07.fits")

plt.figure(figsize=(16,7))
plt.imshow(gal_diff[0].data[0],cmap='magma',norm=LogNorm(),origin='lower')
plt.colorbar()
plt.ylabel('Pixels')
plt.xlabel('Pixels')
plt.show()

# %%
from BinnedAnalysis import *

# %%
obs1 = BinnedObs(srcMaps='3C66A_srcmaps.fits',
                expCube='3C66A_ltcube.fits',
                binnedExpMap='3C66A_expcube.fits',
                irfs='CALDB')
analysis1 = BinnedAnalysis(obs1,srcModel='3C66A_model.xml', optimizer='MINUIT')
analysis1.fit()
analysis1.model
# Out:
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-17-7bdf892170eb> in <module>()
#       3                 binnedExpMap='3C66A_expcube.fits',
#       4                 irfs='CALDB')
# ----> 5 analysis1 = BinnedAnalysis(obs1,srcModel='3C66A_model.xml', optimizer='MINUIT')
#       6 analysis1.fit()
#       7 analysis1.model
#
# /home/emiliano-vp/.conda/envs/fermi/lib/python2.7/site-packages/fermitools/BinnedAnalysis.pyc in __init__(self, binnedData, srcModel, optimizer, use_bl2, verbosity, psfcorr, wmap, config, delete_local_fixed)
#     177         self.verbosity = verbosity
#     178         self.logLike.initOutputStreams()
# --> 179         self.logLike.readXml(srcModel, _funcFactory, False, True, False)
#     180         self.model = SourceModel(self.logLike, srcModel)
#     181         self.energies = num.array(self.logLike.energies())
#
# ...

# %%
obs2 = BinnedObs(srcMaps='BBJ01_srcmaps.fits',
                expCube='BBJ01_ltcube.fits',
                binnedExpMap='BBJ01_expcube.fits',
                irfs='CALDB')
analysis2 = BinnedAnalysis(obs2,srcModel='BBJ01_model.xml', optimizer='MINUIT')
analysis2.fit()
analysis2.model
# Out:
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-18-b16555ad64d5> in <module>()
#       3                 binnedExpMap='BBJ01_expcube.fits',
#       4                 irfs='CALDB')
# ----> 5 analysis2 = BinnedAnalysis(obs2,srcModel='BBJ01_model.xml', optimizer='MINUIT')
#       6 analysis2.fit()
#       7 analysis2.model
#
# /home/emiliano-vp/.conda/envs/fermi/lib/python2.7/site-packages/fermitools/BinnedAnalysis.pyc in __init__(self, binnedData, srcModel, optimizer, use_bl2, verbosity, psfcorr, wmap, config, delete_local_fixed)
#     177         self.verbosity = verbosity
#     178         self.logLike.initOutputStreams()
# --> 179         self.logLike.readXml(srcModel, _funcFactory, False, True, False)
#     180         self.model = SourceModel(self.logLike, srcModel)
#     181         self.energies = num.array(self.logLike.energies())
#
# ...

# %%
obs3 = BinnedObs(srcMaps='BBJ11_srcmaps.fits',
                expCube='BBJ11_ltcube.fits',
                binnedExpMap='BBJ11_expcube.fits',
                irfs='CALDB')
analysis3 = BinnedAnalysis(obs3,srcModel='BBJ11_model.xml', optimizer='MINUIT')
analysis3.fit()
analysis3.model
# Out:
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-19-4cd1af2dba2a> in <module>()
#       3                 binnedExpMap='BBJ11_expcube.fits',
#       4                 irfs='CALDB')
# ----> 5 analysis3 = BinnedAnalysis(obs3,srcModel='BBJ11_model.xml', optimizer='MINUIT')
#       6 analysis3.fit()
#       7 analysis3.model
#
# /home/emiliano-vp/.conda/envs/fermi/lib/python2.7/site-packages/fermitools/BinnedAnalysis.pyc in __init__(self, binnedData, srcModel, optimizer, use_bl2, verbosity, psfcorr, wmap, config, delete_local_fixed)
#     177         self.verbosity = verbosity
#     178         self.logLike.initOutputStreams()
# --> 179         self.logLike.readXml(srcModel, _funcFactory, False, True, False)
#     180         self.model = SourceModel(self.logLike, srcModel)
#     181         self.energies = num.array(self.logLike.energies())
#
# ...

# %%
from UnbinnedAnalysis import *
obs11 = UnbinnedObs('3C66A_mktime.fits','3C66A_SC.fits',expMap='3C66A_expcube.fits',expCube='3C66A_ltcube.fits',irfs='CALDB')
analysis11 = UnbinnedAnalysis(obs11,'3C279_model.xml',optimizer='NewMinuit')
# Out:
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-2-0c83784e6c3f> in <module>()
#       1 from UnbinnedAnalysis import *
#       2 obs = UnbinnedObs('3C66A_mktime.fits','3C66A_SC.fits',expMap='3C66A_expcube.fits',expCube='3C66A_ltcube.fits',irfs='CALDB')
# ----> 3 like = UnbinnedAnalysis(obs,'3C279_model.xml',optimizer='NewMinuit')
#
# /home/emiliano-vp/.conda/envs/fermi/lib/python2.7/site-packages/fermitools/UnbinnedAnalysis.pyc in __init__(self, observation, srcModel, optimizer, nee)
#     152         self.logLike = pyLike.LogLike(self.observation.observation)
#     153         self.logLike.initOutputStreams()
# --> 154         self.logLike.readXml(srcModel, _funcFactory, True, True, False)
#     155         self.logLike.computeEventResponses()
#     156         self.model = SourceModel(self.logLike, srcModel)
#
# ...

# %%
ls .conda/share/fermitools/refdata/fermi/galdiffuse
# Out:
# ls: no se puede acceder a '.conda/share/fermitools/refdata/fermi/galdiffuse': No existe el archivo o el directorio
